# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Importing the Data**

# %%
titanic = pd.read_csv(r'C:\Users\praveen\Downloads\Titanic-Dataset.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # **Expolring the data**

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.isnull().sum() #titanic.Cabin.isnull()_use-to-see-paticular-column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic[titanic['Cabin'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
titanic.Cabin.isnull().sum()/titanic.shape[0]*100
# Out:
# 77.10437710437711

# %%
titanic.Age.isnull().sum()/titanic.shape[0]*100
# Out:
# 19.865319865319865

# %% [markdown]
# # **data preprocessing/data cleaning & Feature Engineering**

# %% [markdown]
# As by the above insights we get to know 77% of the Cabin Column Is represented by Null values[Cloumn will be dropped]
# Null values in Age can be replaced by mean/average
# Nulls in Embarked will be dropped
# also

# %%
titanic.drop(['PassengerId','Cabin' ,'Ticket','Name'],axis = 1 , inplace = True)

# %%
titanic
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
titanic.Age.fillna(titanic.Age.mean(),inplace = True)

# %%
titanic['Age'].isnull().sum()
# Out:
# 0

# %%
titanic.dropna(inplace = True)
titanic.shape #2-rows-dropped-bcoz-of-2nulls-in-embarked_column
# Out:
# (889, 8)

# %%
titanic['Sex'] = titanic['Sex'].map({'male':0,'female':1})
titanic['Sex']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: Sex, Length: 889, dtype: int64

# %%
#converting_Categorical_variable_into-Numerical_values_____-one-hot-encoding/get_dummies
ports = pd.get_dummies(titanic.Embarked, prefix = 'Embarked')
ports
# Out:
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 886           0           0           1
# 887           0           0           1
# 888           0           0           1
# 889           1           0           0
# 890           0           1           0
#
# [889 rows x 3 columns]

# %%
titanic.drop(['Embarked'],axis = 1, inplace = True)
titanic = titanic.join(ports)

# %%
titanic #now-entire-data-isin-numerical_form
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked_C  \
# 0           0       3    0  22.000000      1      0   7.2500           0
# 1           1       1    1  38.000000      1      0  71.2833           1
# 2           1       3    1  26.000000      0      0   7.9250           0
# 3           1       1    1  35.000000      1      0  53.1000           0
# 4           0       3    0  35.000000      0      0   8.0500           0
# ..        ...     ...  ...        ...    ...    ...      ...         ...
# 886         0       2    0  27.000000      0      0  13.0000           0
# 887         1       1    1  19.000000      0      0  30.0000           0
# 888         0       3    1  29.699118      1      2  23.4500           0
# 889         1       1    0  26.000000      0      0  30.0000           1
# 890         0       3    0  32.000000      0      0   7.7500           0
#
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# ...

# %% [markdown]
# # **splitting-training&model-fitting**

# %%
X = titanic.drop(['Survived'], axis = 1)
y = titanic.Survived.copy()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test ,y_train , y_test = train_test_split(X,y , test_size = 0.2 , random_state = 7)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train , y_train)
# Out:
# C:\Users\praveen\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X_train,y_train)
# Out:
# 0.8073136427566807

# %%
model.score(X_test,y_test)
# Out:
# 0.7752808988764045
